# %%
#from PyEMD.EMD2d import EMD2D
from PyEMD.EMD import EMD
from matplotlib import pyplot as plt
import numpy as np
emd = EMD()

# %%
#df = pd.read_csv('FirstDataFrame1.csv')
x = np.linspace(0, 50, 1000)
y = np.sin(x)*np.cos(x) + 2*np.sin(3*x)
deco = emd.emd(y)

# %%
#img = cv2.imread('DATA/image_00041.jpg', 0)
#ms.Show(img, 'RGB')
plt.plot(x, deco[0])

# %%
plt.plot(x, deco[1])

# %%
plt.plot(x, deco[2])

# %%
plt.plot(x, deco[3])

#deco = emd.emd(img)

# %%
plt.plot(x, deco[4])

# %%
plt.plot(x, y)

# %%
plt.plot(x, deco[1])

# %%
np.sum(deco[0] + deco[1] + deco[2]  - y)
# Out:
# -0.0425487511423317

# %%
emd.find_extrema(x,y)
# Out:
# (array([ 1.55155155,  7.85785786, 14.11411411, 20.42042042, 26.72672673,
#         32.98298298, 39.28928929, 45.54554555]),
#  array([0.99981483, 0.99999249, 0.9997343 , 1.        , 0.99973114,
#         0.99999301, 0.99981219, 0.99997151]),
#  array([ 4.7047047 , 11.01101101, 17.26726727, 23.57357357, 29.82982983,
#         36.13613614, 42.39239239, 48.6986987 ]),
#  array([-0.99997048, -0.99988086, -0.99993396, -0.99993239, -0.99988295,
#         -0.99996942, -0.99981744, -0.99999195]),
#  array([  0,  62, 125, 188, 251, 313, 376, 439, 502, 564, 627, 690, 753,
#         815, 878, 941], dtype=int64))
