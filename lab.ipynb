# %%
import matplotlib.pyplot as plt 
import numpy as np 
from PyEMD import EMD

# %%
t = np.linspace(0, 10, 1000)
signal = lambda f: np.sin(2*np.pi*t)
s = signal(2)

emd = EMD()

"""
emd(s) where s is the signal , returns N tuples, each of which represent the IMF values along the domain (in this case t).
Hence we have N tuples (t, IMF[k]) each representing an IMF.
"""
IMFs = EMD().emd(s)
N = IMFs.shape[0]+1

# Plot results
plt.subplot(N,1,1)
plt.plot(t, s, 'r')
plt.title("Input signal")
plt.xlabel("Time [s]")

for n, imf in enumerate(IMFs):
    plt.subplot(N,1,n+2)
    plt.plot(t, imf, 'g')
    plt.title("IMF "+str(n+1))
    plt.xlabel("Time [s]")

plt.tight_layout()
plt.savefig('simple_example')
plt.show()
